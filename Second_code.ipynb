# %% [markdown]
# <a href="https://colab.research.google.com/github/ValkryreMalachie/First-code/blob/Additions/Second_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def join_with_and(items):
    if not items:
        return ""
    if len(items) == 1:
        return str(items[0])
    if len(items) == 2:
        return f"{items[0]} and {items[1]}"
    return f"{', '.join(items[:-1])}, and {items[-1]}"

students = []

while True: # Capital T!
    name = input("Enter name: ")
    age = input("Enter age: ")
    grade = input("Enter grade: ")

    student_info = {
        "name": name,
        "age": age,
        "grade": grade
    }

    # (Ghost brace deleted)

    students.append(student_info)
    print(f"Added {name} to the list!") # Added 'f' and fixed quotes

    cont = input("Add another student? (y/n): ")
    if cont.lower() == "n":
        break

print("\nFinal Student List:")
all_names = [s['name'] for s in students]
all_ages = [s['age'] for s in students]
all_grades = [s['grade'] for s in students]
print(f"Welcome students {join_with_and(all_names)}, you are aged {join_with_and(all_ages)}, and are in grades {join_with_and(all_grades)}.")
# Out:
# Enter name: Aiden
# Enter age: 17
# Enter grade: A
# Added Aiden to the list!
# Add another student? (y/n): y
# Enter name: Alivia
# Enter age: 15
# Enter grade: C
# Added Alivia to the list!
# Add another student? (y/n): y
# Enter name: Charles
# Enter age: 14
# Enter grade: C
# Added Charles to the list!
# Add another student? (y/n): y
# Enter name: Oscar
# Enter age: 13
# Enter grade: d
# Added Oscar to the list!
# Add another student? (y/n): n
#
# Final Student List:
# Welcome students Aiden, Alivia, Charles, and Oscar, you are aged 17, 15, 14, and 13, and are in grades A, C, C, and d.

# %%
print(f"All Ages: {', '.join(all_ages)}")
print(f"All Grades: {', '.join(all_grades)}")
# Out:
# All Ages: 17, 15, 14, 13
# All Grades: A, C, C, d
