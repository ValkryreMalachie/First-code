# %% [markdown]
# <a href="https://colab.research.google.com/github/ValkryreMalachie/First-code/blob/Student-creation/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def join_with_and(items):
  if not items:
    return ""
  if len(items) == 1:
    return str(items[0])
  if len(items) == 2:
   return f"{items[0]} and {items[1]}"
  return f"{', '.join(items[:-1])}, and {items[-1]}"

def join_with_you(items):
  pass # This function is currently undefined in your notebook, added a pass statement.

students = []
while True:

  name = input("Enter name: ")
  age = input("Enter age: ")
  grade_level = input("Enter grade level: ")
  total_grade = input("Enter your overall grade: ")

  students_info = {
    "name": name,
    "age": age,
    "grade_level": grade_level,
    "total grade": total_grade

    }
  students.append(students_info)
  print(f"Added {name} to the list!!")

  def honor_roll (items):
    if total_grade: A
      print("Student is on the honor roll")
      else:
        print("Student is not on the honor roll")



  # This variable is currently not used, but is kept as it was in the original code.
  grade_count = []

  for s in student:



  cont = input("Do you want to add another student: [y/n]")
  if cont.lower() == "n":
    break


print(f"\n Test Student list")
# Determine if words should be pluralized
if len(students) > 1:
  age_word = "ages"
else:
  age_word = "age"



  if len(students) > 1:
    name_word ="students"
  else:
    name_word = "student"



  # Corrected pluralization for 'grade_word' based on the number of students
  if len(students) > 1:
    grade_word = "grade_level"
  else:
    grade_word = "grade_levels"

# Corrected loop to iterate over the 'students' list
for individual_student in students:
    print(f"Welcome to school {name_word} {individual_student['name']}, you are {age_word} {individual_student['age']}, and within {grade_word} {individual_student['grade']}")
# Out:
#   File "/tmp/ipykernel_348/3176553327.py", line 34
#     for s in student
#                     ^
# SyntaxError: expected ':'

# %%
# Extract student names into a new list
student_names = [student['name'] for student in students]

# Use the join_with_and function with the list of names
joined_names = join_with_and(student_names)

# Print the result
print(f"All students: {joined_names}")

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# ## Google Colab is available in VS Code!
# ![logo.webp](data:image/webp;base64,...)
#
# Try the new [Google Colab extension](https://marketplace.visualstudio.com/items?itemName=Google.colab) for Visual Studio Code. You can get up and running in just a few clicks:
#
# *  In VS Code, open the ***Extensions*** view and search for 'Google Colab' to install.
# *  Open the kernel selector by creating or opening any `.ipynb` notebook file in your local workspace and either running a cell or clicking the ***Select Kernel*** button in the top right.
# *  Click ***Colab*** and then select your desired runtime, sign in with your Google account, and you're all set!
#
# See more details in our [announcement blog here](https://developers.googleblog.com/google-colab-is-coming-to-vs-code).

# %% [markdown]
# ## 🎁 Free Pro Plan for Gemini & Colab for US College Students 🎓
#
# Get more access to our most accurate model Gemini 3 Pro for advanced coding, complex research, and innovative projects, backed by Colab’s dedicated high-compute resources for data science and machine learning.
#
# Get the Gemini free offer at [gemini.google/students](https://gemini.google/students?utm_source=colab&utm_medium=banner&utm_campaign=students_xpa_us-colab-banner).
# Get the Colab free offer at [colab.research.google.com/signup](https://colab.research.google.com/signup).
# Terms Apply.

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %% [markdown]
# Equation Section

# %%
def multiply (a, b):
  result = a * b
  return result

def addition (a,b):
  result = a + b
  return result

def substraction (a,b):
  result = a - b
  return result

def division (a,b):
  result = a // b
  return result

def power (a,b):
  result = a ** b
  return result

print(f"The result of 5 multiplied by 3 is: {multiply(5, 3)}")
print(f"The result of 5 added by 3 is : {addition(5, 3)}")
print(f"The result of 5 subtracted by 3 is: {substraction(5, 3)}")
print(f"The result of 12 divided by 3 is : {division(12, 3)}")
print(f"The result of 5 to the power of 3 is : {power(5, 3)}")

# %% [markdown]
# Schooling Section

# %%
def join_with_and(items):
  if not items:
    return ""
  if len(items) == 1:
    return str(items[0])
  if len(items) == 2:
   return f"{items[0]} and {items[1]}"
  return f"{', '.join(items[:-1])}, and {items[-1]}"

def join_with_you(items):
  pass # This function is currently undefined in your notebook, added a pass statement.

def honor_roll (total_grade):
  if total_grade == 'A':
    print("Student is on the honor roll")
  else:
    print("Student is not on the honor roll")


students = []
while True:

  name = input("Enter name: ")
  age = input("Enter age: ")
  grade_level = input("Enter grade level: ")
  total_grade = input("Enter your overall grade: ")

  students_info = {
    "name": name,
    "age": age,
    "grade_level": grade_level,
    "total grade": total_grade

    }
  students.append(students_info)
  print(f"Added {name} to the list!!")

  honor_roll(total_grade) # Call the function here

  # This variable is currently not used, but is kept as it was in the original code.
  grade_count = []

  # This 'for' loop for 's in student' is incorrect and has been removed.
  # It was attempting to iterate over a single dictionary named 'student'.

  cont = input("Do you want to add another student: [y/n]")
  if cont.lower() == "n":
    break


print(f"\n Test Student list")
# Determine if words should be pluralized
if len(students) > 1:
  age_word = "ages"
else:
  age_word = "age"



if len(students) > 1:
  name_word ="students"
else:
  name_word = "student"



# Corrected pluralization for 'grade_word' based on the number of students
if len(students) > 1:
  grade_word = "grade_levels"
else:
  grade_word = "grade_level"

# Corrected loop to iterate over the 'students' list
for individual_student in students:
    print(f"Welcome to school {name_word} {individual_student['name']}, you are {age_word} {individual_student['age']}, and within {grade_word} {individual_student['grade_level']}")

# %% [markdown]
# Student id section

# %%
import random

def generate_random_id():
    # Generate a random integer ID (e.g., between 10000 and 99999)
    return random.randint(10000, 99999)

students = [
  {"Name": "Alex", "Age": 15, "grade_level": 12, "total_Grade": "A", "status": "Enrolled" },
  {"Name": "Bob", "Age": 15, "grade_level": 10, "total_Grade": "B", "status": "Unenrolled"},
  {"Name": "Charlie", "Age": 16, "grade_level": 11, "total_Grade": "C", "status": "Truant"}
]

terms = {
  "Passed": ["A","B","C"],
  "Failed": ["F","E","D","C"]
}

reason_for_status = {
    "Enrolled": "Enrolled in school",
    "Unenrolled": "Not enrolled in school",
    "Truant": "Failed"
}

# Assign a unique random ID to each student
# You might want to ensure IDs are truly unique if generating many
for student_data in students:
    student_data["id"] = generate_random_id()

# Print students with their new IDs to verify
for student_data in students:
    print(f"Student: {student_data['Name']}, ID: {student_data['id']}")

# Corrected list comprehensions
all_names = [s['Name'] for s in students]
all_ages = [s['Age'] for s in students]
all_grade_level = [s['grade_level'] for s in students]
all_total_Grade = [s['total_Grade'] for s in students]
all_status = [s['status'] for s in students]
all_id = [s['id'] for s in students]


print("\n students + info list")
print(f"All names: {', '.join(all_names)}")
print(f"All ages: {', '.join(map(str, all_ages))}")
print(f"All grade levels: {', '.join(map(str, all_grade_level))}")
print(f"All total grades: {', '.join(all_total_Grade)}")
print(f"All statuses: {', '.join(all_status)}")
print(f"All IDs: {', '.join(map(str, all_id))}")
# Out:
# Student: Alex, ID: 64552
# Student: Bob, ID: 56275
# Student: Charlie, ID: 16408
#
#  students + info list
# All names: Alex, Bob, Charlie
# All ages: 15, 15, 16
# All grade levels: 12, 10, 11
# All total grades: A, B, C
# All statuses: Enrolled, Unenrolled, Truant
# All IDs: 64552, 56275, 16408

# %%
""

# %% [markdown]
# # Task
# Fix the syntax errors in the `terms` and `reason_for_status` blocks in the code cell `jwzgN8IrcIPe`, correctly assign random IDs to students, and extract student information into separate lists using accurate list comprehensions that iterate over the `students` list with the correct dictionary keys.

# %% [markdown]
# ## Fix Code Errors
#
# ### Subtask:
# Correct the syntax errors in the `terms` and `reason_for_status` blocks, and fix the list comprehensions to correctly extract data from the `students` list.

# %% [markdown]
# **Reasoning**:
# The subtask requires correcting syntax errors in the `terms` and `reason_for_status` blocks, fixing key inconsistencies in the `students` list, and updating list comprehensions in cell `jwzgN8IrcIPe`. I will generate a single code block with all the necessary fixes.

# %%
import random

def generate_random_id():
    # Generate a random integer ID (e.g., between 10000 and 99999)
    return random.randint(10000, 99999)

students = [
  {"Name": "Alex", "Age": 15, "grade_level": 12, "total_Grade": "A", "status": "Enrolled" },
  {"Name": "Bob", "Age": 15, "grade_level": 10, "total_Grade": "B", "status": "Unenrolled"},
  {"Name": "Charlie", "Age": 16, "grade_level": 11, "total_Grade": "C", "status": "Truant"}
]

terms = {
  "Passed": ["A","B","C"],
  "Failed": ["F","E","D","C"]
}

reason_for_status = {
    "Enrolled": "Enrolled in school",
    "Unenrolled": "Not enrolled in school",
    "Truant": "Failed"
}

# Assign a unique random ID to each student
# You might want to ensure IDs are truly unique if generating many
for student_data in students:
    student_data["id"] = generate_random_id()

# Print students with their new IDs to verify
for student_data in students:
    print(f"Student: {student_data['Name']}, ID: {student_data['id']}")

# Corrected list comprehensions
all_names = [s['Name'] for s in students]
all_ages = [s['Age'] for s in students]
all_grade_level = [s['grade_level'] for s in students]
all_total_Grade = [s['total_Grade'] for s in students]
all_status = [s['status'] for s in students]
all_id = [s['id'] for s in students]
# Out:
# Student: Alex, ID: 41352
# Student: Bob, ID: 95706
# Student: Charlie, ID: 32212

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the code now runs without errors and correctly assigns random IDs to students and extracts their information.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The code now runs without errors, successfully assigning random IDs to students and extracting their information using correct list comprehensions.
#
# ### Data Analysis Key Findings
# *   Syntax errors in both the `terms` and `reason_for_status` dictionaries were successfully corrected, ensuring proper dictionary structure.
# *   A unique random ID was generated and assigned to each student; for example, Alex received ID 41352, Bob received ID 95706, and Charlie received ID 32212 (specific IDs may vary due to random generation).
# *   All student information, including names, ages, grade levels, total grades, statuses, and newly assigned IDs, was accurately extracted into separate lists using correct list comprehensions.
#
# ### Insights or Next Steps
# *   The implemented solution provides a robust foundation for managing student data, enabling further analysis or integration with other systems.
# *   For larger datasets or long-term storage, consider implementing a more sophisticated ID generation and management system to ensure global uniqueness and avoid potential collisions.
